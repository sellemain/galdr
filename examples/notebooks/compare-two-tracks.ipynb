# %% [markdown]
# # compare two tracks

# %% [markdown]
# Run two analyses, then use the existing comparison module.

# %%
from galdr import listen
from galdr.compare import compare_tracks

a = listen('audio/track-a.mp3', name='track-a')
b = listen('audio/track-b.mp3', name='track-b')
compare_tracks(a.slug, b.slug, 'analysis')
