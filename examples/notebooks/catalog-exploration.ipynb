# %% [markdown]
# # catalog exploration

# %% [markdown]
# Load stream JSON into pandas and explore patterns.

# %%
from galdr import Analysis

a = Analysis.from_slug('your-track', analysis_dir='analysis')
frames = a.to_dataframes()
frames.keys()

# %%
df = frames.get('perception')
if df is not None:
    display(df.head())
    df.plot(x='t', y=['attention', 'pattern'], figsize=(12, 4))
